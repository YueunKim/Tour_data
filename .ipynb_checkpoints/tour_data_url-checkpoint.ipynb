# %% [markdown]
# ## Code Build-up에 도움된 자료
#
# ### https://greendreamtrre.tistory.com/268
#   - queryParams 부분의 깔끔한 코드 + 자세한 코드 + 행렬 설명이 도움됨.
#
#
# ### https://seonu-lim.github.io/python/Using-API/
#   - queryParams 부분의 코드가 매우 깔끔해서 인상깊음.
#
# ### https://kibua20.tistory.com/159
#   - unquote : 서버나 브라우저가 인식하기 좋은 ascii 값으로 변환하는 것이 아닌 사람이 읽을 수 있는 값으로 변환하는 함수
#
# ### https://hogni.tistory.com/19
#   - dataframe을 엑셀로 저장하는 방법 설명이 매우 우수

# %%
import requests, bs4
import pandas as pd
from lxml import html
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote

# 1. URL 파라미터 분리하기.
# Service URL - 관광사진 갤러리 조회
xmlUrl = 'http://api.visitkorea.or.kr/openapi/service/rest/PhotoGalleryService/galleryList'

API_key = unquote('IB3QISfc1ZNgH+CPuMgUoMEgSvbuGsMig/eIFRGai1inB3AdCo4z2g5hCVdbd8dMwf6DYoFP3bnqO+s7Iplmww==')
queryParams = '?' + urlencode(    # get 방식으로 쿼리를 분리하기 위해 '?'를 넣은 것이다. 메타코드 아님.
    {
        quote_plus('ServiceKey') : API_key,    # 필수 항목 1 : 서비스키 (본인의 서비스키)
        quote_plus('MobileOS') : 'ETC',          # 필수 항목 2 : OS 구분 (IOS - 아이폰, AND - 안드로이드, WIN - 윈도우폰, ETC)
        quote_plus('MobileApp') : 'AppTest',         # 필수 항목 3 : 서비스명=어플명
        quote_plus('numOfRows') : '3104'            # 옵션 : 입력값은 데이터 참고문서 참고, 입력 안할시 10개의 데이터만 보여짐.
    }
)

response = requests.get(xmlUrl + queryParams).text.encode('utf-8')
xmlobj = bs4.BeautifulSoup(response, 'lxml-xml')
# xmlobj    # 디버깅용

rows = xmlobj.findAll('item')
# rows    # 디버깅용 - item 태그 단위로 구분
columns = rows[0].find_all()
# columns    # 디버깅용.
# columns[0].name    # 디버깅용.
# columns[0].text    # 디버깅용.

# 모든 행과 열의 값을 모아 매트릭스로 만들어보자.
rowList = []
nameList = []
columnList = []

rowsLen = len(rows)
for i in range(0, rowsLen):
    columns = rows[i].find_all()
    
    columnsLen = len(columns)
    for j in range(0, columnsLen):
        # 첫 번째 행 데이터 값 수집 시에만 컬럼 값을 저장한다. (어차피 rows[0], rows[1], ... 모두 컬럼헤더는 동일한 값을 가지기 때문에 매번 반복할 필요가 없다.)
        if i == 0:
            nameList.append(columns[j].name)
        # 컬럼값은 모든 행의 값을 저장해야한다.    
        eachColumn = columns[j].text
        columnList.append(eachColumn)
    rowList.append(columnList)
    columnList = []    # 다음 row의 값을 넣기 위해 비워준다. (매우 중요!!)
    
result = pd.DataFrame(rowList, columns=nameList)
result.to_excel('api_data.xlsx')
result
# Out:
#      galContentId galContentTypeId  galCreatedtime galModifiedtime  \
# 0         2719605               17  20210603152448  20210603152506
# 1         2717990               17  20210524181811  20210524181825
# 2         2717942               17  20210524173546  20210524173600
# 3         2717931               17  20210524161712  20210524161728
# 4         2717833               17  20210524145830  20210524145912
# ...           ...              ...             ...             ...
# 3099      1733904               17  20121016163828  20150706105541
# 3100      1733939               17  20121016165448  20150706105427
# 3101      1733385               17  20121016094234  20150706102745
# 3102      1733229               17  20121015170207  20150706102044
# 3103      1733069               17  20121015154630  20150706101037
#
#      galPhotographer galPhotographyLocation galPhotographyMonth  \
# 0         한국관광공사 김지호           전라북도 김제시 금산면              202105
# 1         한국관광공사 이범수           충청남도 서산시 해미면              202105
# 2         한국관광공사 이범수           충청남도 서산시 운산면              202105
# 3         한국관광공사 이범수            경기도 안성시 공도읍              202105
# 4         한국관광공사 이범수            경기도 안성시 보개면              202105
# ...              ...                    ...                 ...
# 3099      한국관광공사 김지호          대구광역시 의료선교박물관              201209
# 3100      한국관광공사 김지호                  대구광역시              201209
# 3101      한국관광공사 김지호                  대구광역시              201209
# 3102      한국관광공사 김지호                  대구광역시              201209
# 3103      한국관광공사 김지호                  대구광역시              201209
#
#                                        galSearchKeyword    galTitle  \
# 0     금제 금산사, 전라북도 김제시, 절, 사찰, 종교, 불교, 모악산, 국보 제62호,...      김제 금산사
# 1     서산 해미읍성, 충청남도 서산시, 사적 제116호, 성곽, 드론촬영, 드론사진, 항공촬영     서산 해미읍성
# 2                       서산 문수사, 충청남도 서산시, 절, 사찰, 종교, 불교      서산 문수사
# 3                       안성팜랜드, 경기도 안성시, 테마파크, 공원, 체험관광지       안성팜랜드
# 4         안성맞춤랜드, 경기도 안성시, 테마공원, 수변공원, 드론촬영, 드론사진, 항공촬영      안성맞춤랜드
# ...                                                 ...         ...
# 3099                                 대구 능금의 효시, 백년 사과나무   대구 능금의 효시
# 3100                                  계명대학교 동산병원, 동산의료원  계명대학교 동산병원
# 3101                                               옻골마을        옻골마을
# 3102                                  경주최씨 종택, 종가, 옻골마을     경주최씨 종택
# 3103                                          동계정, 옻골마을         동계정
#
#      galViewCount                                     galWebImageUrl
# 0              33  http://tong.visitkorea.or.kr/cms2/website/05/2...
# 1              12  http://tong.visitkorea.or.kr/cms2/website/90/2...
# 2               4  http://tong.visitkorea.or.kr/cms2/website/42/2...
# 3               8  http://tong.visitkorea.or.kr/cms2/website/31/2...
# 4              12  http://tong.visitkorea.or.kr/cms2/website/33/2...
# ...           ...                                                ...
# 3099           46  http://tong.visitkorea.or.kr/cms2/website/04/1...
# 3100           37  http://tong.visitkorea.or.kr/cms2/website/39/1...
# 3101          108  http://tong.visitkorea.or.kr/cms2/website/85/1...
# 3102          137  http://tong.visitkorea.or.kr/cms2/website/29/1...
# 3103           47  http://tong.visitkorea.or.kr/cms2/website/69/1...
#
# [3104 rows x 11 columns]
